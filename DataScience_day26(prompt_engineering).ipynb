# %% [markdown]
# ![image.png](attachment:983de161-a2ee-4f3f-b366-8c235607b26c.png)

# %% [markdown]
# ![image.png](attachment:8c1e788f-a562-47af-8811-8d14212aabb6.png)

# %% [markdown]
# ![image.png](attachment:f3b17a27-b90c-4eac-ae4f-06f9baed598d.png)

# %% [markdown]
# ![image.png](attachment:207a2a5f-b675-4397-81b9-0c21ebc5234b.png)

# %% [markdown]
# ![image.png](attachment:36553645-0a1c-40e8-8b98-bcf5a5d739cc.png)

# %% [markdown]
# ![image.png](attachment:08d59d9f-df2d-40fc-8f34-c7b1d97a1668.png)
