# %% [markdown]
# H0: coin is fair(p_head=0.5)
# H1:p_head<0.5

# %%
n=10
p_head=10
ob_head(observe)=0.05
alpha=0.05

# pvalue<alpha, reject H0
pvalue=p(head<=2)

# %% [markdown]
# Scipy is the library used for the Scientific and Engineering
# - it is the extended form of the numpy
# - there are some modules in the scipy
#       scipy.stats
#       scipy.optmize=> root finding, curve finding
#       scipy.integrate
#       scipy.linalg=> provide advanced linear algebra routine

# %% [markdown]
# scipy.stats=> is used for mathematical compution
# - here we want binomial so import binom for compution using scipy.stat

# %%
pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade scipy

# %%
from scipy.stats import binom

# %%
from scipy.stats import binom
n=10
p_head=0.5
ob_head=2
alpha=0.05

# pvalue<alpha, reject H0
#pvalue=p(head<=2)
pvalue=binom.cdf(ob_head,n,p_head)

# %%
pvalue
# Out:
# np.float64(0.0546875)

# %%
if pvalue<alpha:
    print('Reject H0')

else:
    print('Dont Reject H0')
# Out:
# Dont Reject H0
